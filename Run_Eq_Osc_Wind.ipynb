# %%
import matplotlib as plt
# %matplotlib inline

# %run -i Run_Eq_Osc_Wind.py
# Out:
# Vertical mode 0 , Meridional mode 0 == Farrar & Durland (2012): bc 1 m 0
# Computing PS for splines also...
#
#
#
# Vertical mode 0 , Meridional mode 1 == Farrar & Durland (2012): bc 1 m 1
# Computing PS for splines also...
#
#
#
# Vertical mode 0 , Meridional mode 2 == Farrar & Durland (2012): bc 1 m 2
# Computing PS for splines also...
#
#
#
# Vertical mode 0 , Meridional mode 3 == Farrar & Durland (2012): bc 1 m 3
# Computing PS for splines also...
#
#
#
# Vertical mode 0 , Meridional mode 4 == Farrar & Durland (2012): bc 1 m 4
# Computing PS for splines also...
#
#
#
# Vertical mode 0 , Meridional mode 5 == Farrar & Durland (2012): bc 1 m 5
# Computing PS for splines also...
#
#
#
# Vertical mode 1 , Meridional mode 0 == Farrar & Durland (2012): bc 2 m 0
# Computing PS for splines also...
#
#
#
# Vertical mode 1 , Meridional mode 1 == Farrar & Durland (2012): bc 2 m 1
# Computing PS for splines also...
#
#
#
# ...
